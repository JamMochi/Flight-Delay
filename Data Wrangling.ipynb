# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
flights_df = pd.read_csv("C:\\Users\\henry\\Desktop\\Flights\\Data\\flights.csv")
# Out:
# C:\Users\henry\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
flights_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %%
flights_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
flights_df.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %% [markdown]
# Perform a brief overview on flight data using .info(), .head(), and .describe().
#
# Things we should focus on changing.
# - year, month, and day are type int64. We should probably convert this to datetime because the describe statistic for this column does not make too much sense.
#
# - day_of_week should probably be categorical
#
# - some of the time formats are strange some modification is needed.

# %% [markdown]
# # # Data Cleaning - Missing Values

# %%
missing_count = flights_df.isna().sum(axis=0)
missing_percentage = missing_count / len(flights_df)
missing_df = pd.DataFrame({'count': missing_count, '%': missing_percentage})

# %%
missing_df
missing_df.sort_values(by='%', ascending=False).head(10)
# Out:
#                        count         %
# CANCELLATION_REASON  5729195  0.984554
# WEATHER_DELAY        4755640  0.817250
# LATE_AIRCRAFT_DELAY  4755640  0.817250
# AIRLINE_DELAY        4755640  0.817250
# SECURITY_DELAY       4755640  0.817250
# AIR_SYSTEM_DELAY     4755640  0.817250
# AIR_TIME              105071  0.018056
# ARRIVAL_DELAY         105071  0.018056
# ELAPSED_TIME          105071  0.018056
# WHEELS_ON              92513  0.015898

# %% [markdown]
# In this section, I count the number of missing values in each column. I then proceeded in calculating the missing percentage for each column to get the full picture how much data is missing. From the missing_df, we can see that CANCELLATION_REASON, WEATHER_DELAY, LATE_AIRCRAFT_DELAY, AIRLINE_DELAY, SECURITY_DELAY, and AIR_SYSTEM_DELAY all have over 50% of its values missing.
#
# We will now have to explore these missing columns to see if we can fix these before dropping out of our analysis completely.

# %%
columns = ['CANCELLED', 'CANCELLATION_REASON']
cancel_df = flights_df[columns]
cancel_df.head()
# Out:
#    CANCELLED CANCELLATION_REASON
# 0          0                 NaN
# 1          0                 NaN
# 2          0                 NaN
# 3          0                 NaN
# 4          0                 NaN

# %%
print(cancel_df[cancel_df.CANCELLED == 0].isna().sum(axis=0) / len(cancel_df[cancel_df.CANCELLED == 0]))
# Out:
# CANCELLED              0.0
# CANCELLATION_REASON    1.0
# dtype: float64

# %%
cancel_df[cancel_df.CANCELLED == 1]
# Out:
#          CANCELLED CANCELLATION_REASON
# 32               1                   A
# 42               1                   B
# 68               1                   B
# 82               1                   B
# 90               1                   A
# ...            ...                 ...
# 5818090          1                   A
# 5818157          1                   A
# 5818318          1                   A
# 5818777          1                   A
# 5818843          1                   A
#
# [89884 rows x 2 columns]

# %% [markdown]
# From our analysis, we can see that these missing values just represent that the flights are not cancel. Therefore, we do not need to remove this column, but just replace the current missing value with a indicator suggesting that the flight was not canceled.

# %%
columns = ['DEPARTURE_DELAY', 'ARRIVAL_DELAY', 'WEATHER_DELAY', 'LATE_AIRCRAFT_DELAY', 'AIRLINE_DELAY', 'SECURITY_DELAY', 'AIR_SYSTEM_DELAY']
delay_df = flights_df[columns]
delay_df.head(10)
# Out:
#    DEPARTURE_DELAY  ARRIVAL_DELAY  WEATHER_DELAY  LATE_AIRCRAFT_DELAY  \
# 0            -11.0          -22.0            NaN                  NaN
# 1             -8.0           -9.0            NaN                  NaN
# 2             -2.0            5.0            NaN                  NaN
# 3             -5.0           -9.0            NaN                  NaN
# 4             -1.0          -21.0            NaN                  NaN
# 5             -5.0            8.0            NaN                  NaN
# 6             -6.0          -17.0            NaN                  NaN
# 7             14.0          -10.0            NaN                  NaN
# 8            -11.0          -13.0            NaN                  NaN
# 9              3.0          -15.0            NaN                  NaN
#
#    AIRLINE_DELAY  SECURITY_DELAY  AIR_SYSTEM_DELAY
# 0            NaN             NaN               NaN
# 1            NaN             NaN               NaN
# ...

# %% [markdown]
# After looking at the departure_delay and arrival_delay, we cannot really determine why all the missing values exist. Therefore the best thing we can do is to drop all these columns with missing values.

# %%
col = ['WEATHER_DELAY', 'LATE_AIRCRAFT_DELAY', 'AIRLINE_DELAY', 'SECURITY_DELAY', 'AIR_SYSTEM_DELAY']
mod_flights = flights_df.drop(columns=col, axis=1)
mod_flights
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
mod_flights['CANCELLATION_REASON'].value_counts()
# Out:
# B    48851
# A    25262
# C    15749
# D       22
# Name: CANCELLATION_REASON, dtype: int64

# %%
mod_flights.loc[mod_flights.CANCELLED == 0, 'CANCELLATION_REASON'] = 'ON'

# %%
mod_flights.isna().sum(axis=1).value_counts()
# Out:
# 0     5714008
# 10      71432
# 11      14721
# 3       12558
# 6        3460
# 8        2894
# 7           6
# dtype: int64

# %% [markdown]
# We just measure the number of missing value for each entry in the DataFrame, and we can see that about 85,000 entries have 10 to 11 missing value.

# %%
ten_and_greater_missing = mod_flights.loc[mod_flights.isna().sum(axis=1) >= 10, :]

# %%
ten_and_greater_missing.iloc[0:5,:].T
# Out:
#                          32      42      68      82      90
# YEAR                   2015    2015    2015    2015    2015
# MONTH                     1       1       1       1       1
# DAY                       1       1       1       1       1
# DAY_OF_WEEK               4       4       4       4       4
# AIRLINE                  AS      AA      OO      MQ      OO
# FLIGHT_NUMBER           136    2459    5254    2859    5460
# TAIL_NUMBER          N431AS  N3BDAA  N746SK  N660MQ  N583SW
# ORIGIN_AIRPORT          ANC     PHX     MAF     SGF     RDD
# DESTINATION_AIRPORT     SEA     DFW     IAH     DFW     SFO
# SCHEDULED_DEPARTURE     135     200     510     525     530
# DEPARTURE_TIME          NaN     NaN     NaN     NaN     NaN
# DEPARTURE_DELAY         NaN     NaN     NaN     NaN     NaN
# TAXI_OUT                NaN     NaN     NaN     NaN     NaN
# WHEELS_OFF              NaN     NaN     NaN     NaN     NaN
# SCHEDULED_TIME          205     120      87      95      90
# ...

# %% [markdown]
# Look at the entries, we can see that majority of these flights are canceled, therefore those missing values are really just 0s.

# %%
columns_of_interest = ['DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT', 'WHEELS_OFF', 'ELAPSED_TIME', 'AIR_TIME', 'WHEELS_ON', 'TAXI_IN', 'ARRIVAL_TIME', 'ARRIVAL_DELAY']
mod_flights.loc[mod_flights.CANCELLED == 1, columns_of_interest] = 0
mod_flights.isna().sum(axis=1).value_counts()
# Out:
# 0    5789166
# 1      14726
# 3      12558
# 6       2628
# 7          1
# dtype: int64

# %% [markdown]
# # Evaluate Data Type

# %%
mod_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 26 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %% [markdown]
# Some of the columns datatype does not really represent what the data is trying to relay to us. In this section, we will convert the data in this dataframe into its appropriate datatype.

# %%
categorical_data = ['DAY_OF_WEEK', 'FLIGHT_NUMBER']

for col in categorical_data:
    mod_flights[col] = mod_flights[col].astype('category')

# %%
mod_flights['DATE'] = pd.to_datetime(mod_flights[['YEAR', 'MONTH', 'DAY']])

# %%
mod_flights.iloc[3,:].T
# Out:
# YEAR                                  2015
# MONTH                                    1
# DAY                                      1
# DAY_OF_WEEK                              4
# AIRLINE                                 AA
# FLIGHT_NUMBER                          258
# TAIL_NUMBER                         N3HYAA
# ORIGIN_AIRPORT                         LAX
# DESTINATION_AIRPORT                    MIA
# SCHEDULED_DEPARTURE                     20
# DEPARTURE_TIME                          15
# DEPARTURE_DELAY                         -5
# TAXI_OUT                                15
# WHEELS_OFF                              30
# SCHEDULED_TIME                         285
# ELAPSED_TIME                           281
# AIR_TIME                               258
# DISTANCE                              2342
# WHEELS_ON                              748
# TAXI_IN                                  8
# SCHEDULED_ARRIVAL                      805
# ARRIVAL_TIME                           756
# ...

# %%
mod_flights[['SCHEDULED_DEPARTURE', 'DEPARTURE_TIME']].head()
# Out:
#    SCHEDULED_DEPARTURE  DEPARTURE_TIME
# 0                    5          2354.0
# 1                   10             2.0
# 2                   20            18.0
# 3                   20            15.0
# 4                   25            24.0

# %%
def number_to_datetime(number):
    
    if pd.isnull(number):
        return np.nan
    
    number = int(number)
    if number == 2400:
        number = 0
    padded_number = f'{number:04}'
    return datetime.time(int(padded_number[0:2]), int(padded_number[2:4]))

# %%
need_time_adjust = ['SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME']

deepcopy = mod_flights.copy()

for adjust in need_time_adjust:
    deepcopy[adjust] = deepcopy[adjust].apply(number_to_datetime)

# %%
deepcopy.head()
# Out:
#    YEAR  MONTH  DAY DAY_OF_WEEK AIRLINE FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1           4      AS            98      N407AS
# 1  2015      1    1           4      AA          2336      N3KUAA
# 2  2015      1    1           4      US           840      N171US
# 3  2015      1    1           4      AA           258      N3HYAA
# 4  2015      1    1           4      AS           135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE  ... DISTANCE  \
# 0            ANC                 SEA            00:05:00  ...     1448
# 1            LAX                 PBI            00:10:00  ...     2330
# 2            SFO                 CLT            00:20:00  ...     2296
# 3            LAX                 MIA            00:20:00  ...     2342
# 4            SEA                 ANC            00:25:00  ...     1448
#
#    WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# ...

# %%
deepcopy.to_csv('clean_flight_df.csv')
